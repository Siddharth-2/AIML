# %% [markdown]
# K-Means Algorithm

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Load the dataset
df = pd.read_csv('winequality_white.csv')

# Check if the dataset has a header row
if df.columns[0] == 0:
    # If the first column is 0, use the default column names
    df.columns = [f'col_{i}' for i in range(len(df.columns))]

# Standardize the features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df.iloc[:, :-1])  # Exclude the last column (target)

# Split the dataset into features and target
X = df_scaled
y = df.iloc[:, -1]  # Assuming the last column is the target variable

# Create and fit the K-means model
kmeans = KMeans(n_clusters=3, max_iter=400, verbose=True, tol=0.2)
predictions = kmeans.fit_predict(X)

# Plot the data points
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', c='red', s=200, label='Centroids')
plt.title('Wine Quality Dataset - K-Means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 68079.13039922234.
# Iteration 1, inertia 41712.55361799028.
# Iteration 2, inertia 39723.25443676275.
# Converged at iteration 2: center shift 0.17351245602232634 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 52991.92505443073.
# Iteration 1, inertia 40658.09473049183.
# Iteration 2, inertia 40225.301873637916.
# Converged at iteration 2: center shift 0.0973970875716065 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 57194.49550099175.
# Iteration 1, inertia 42178.745819181975.
# Iteration 2, inertia 40330.69906202042.
# Iteration 3, inertia 39576.45976523042.
# Converged at iteration 3: center shift 0.11794109799405056 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 54375.58767537034.
# Iteration 1, inertia 40787.157151641666.
# Iteration 2, inertia 39927.509363309626.
# Converged at iteration 2: center shift 0.08832834077288006 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 63270.416346765625.
# Iteration 1, inertia 43756.53679095902.
# Iteration 2, inertia 40864.025539709604.
# Iteration 3, inertia 40220.05845013497.
# Converged at iteration 3: center shift 0.11525129618842132 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 52364.07821096345.
# Iteration 1, inertia 40640.85236335691.
# Iteration 2, inertia 39847.46044247308.
# Converged at iteration 2: center shift 0.06293466471636387 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 55058.878482176806.
# Iteration 1, inertia 40597.25350871116.
# Iteration 2, inertia 39434.46079826008.
# Converged at iteration 2: center shift 0.05883894592089996 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 63388.93039640755.
# Iteration 1, inertia 42242.86857485158.
# Iteration 2, inertia 40348.454117903195.
# Converged at iteration 2: center shift 0.16598545753865587 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 77331.5964670344.
# Iteration 1, inertia 40874.65011708155.
# Iteration 2, inertia 40149.06966120147.
# Converged at iteration 2: center shift 0.0666829659539487 within tolerance 0.2.
# Initialization complete
# Iteration 0, inertia 50761.42567259609.
# Iteration 1, inertia 39737.49396897679.
# Converged at iteration 1: center shift 0.1722530205371715 within tolerance 0.2.
